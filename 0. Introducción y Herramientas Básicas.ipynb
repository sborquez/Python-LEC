# %% [markdown]
# <center>
# <h1 align="center">Laboratorio de Estadística Computacional <br>con Python</h1>
# <img src="https://raw.githubusercontent.com/sborquez/Python-LEC/master/resources/main-image-python.png" width="60%">
#
# <h2 align="center">Tema 0: Introducción y Herramientas Básicas </h2>
# <i>Notebook creado por Sebastián Bórquez G. - <a href="mailto://sebastian.borquez.g@gmail.com" > sebastian.borquez.g@gmail.com</a> - DI UTFSM - Marzo 2019.</i>
# </center>
#
# ## Tabla de Contenido
#
# * [Preparación del ambiente de desarrollo](#0.1)
#     * [Opcion A: Anaconda](#0.1.a)
#         * [Instalar Anaconda](#0.1.a.1)
#         * [Instalar prerequisitos](#0.1.a.2)
#     * [Opcion B: Google Colab](#0.1.b)
# * [Python](#0.2)
#     * [Guias de estilo](#0.2.1)
#     * [Comprension de listas](#0.2.2)
#     * [Funciones de orden superior e itertool](#0.2.3)
# * [Python para el análisis de datos](#0.3)
#     * [Jupyter Notebook](#0.3.1)
#     * [Numpy](#0.3.2)
#     * [Numpy](#0.3.3)
#     * [Pandas](#0.3.4)
#     * [Matplotlib](#0.3.5)
#     * [Seaborn](#0.3.6)

# %% [markdown]
# <div id="0.1"></div>
#
#
# # Preparación del ambiente de desarrollo
#
#
# <div id="0.1.a"></div>
#
#
# ## Opcion A: Anaconda
#
# <img src="https://www.anaconda.com/wp-content/uploads/2018/06/cropped-Anaconda_horizontal_RGB-1-600x102.png"></img>
#
# [Anaconda](https://www.anaconda.com/distribution/) es un software múltiplataforma open-source para la gestión de paquetes y gestión de ambientes (enviroments). Anaconda es la manera más sencilla de comenzar y gestionar tus proyectos de **Python** o __R__, en especial para proyectos de **[data science](https://www.youtube.com/watch?v=D6j3VS1L96o)** y **[machine learning](https://www.youtube.com/watch?v=oGdmSshtVWw)**. Esta opción es para aquellos que quieran trabajar de manera local en su máquinas.
#
#
# <div id="0.1.a.1"></div>
#
# ### Instalar Anaconda
#
# La instalación incluye varios módulos que necesitaremos (numpy, scikit-learn, scipy, pandas, etc). También es sencillo agregar nuevos módulos utilizando _conda install_ o _pip install_. Además podremos manipular distintas versiones de los módulos o incluso entre **python2** y **python3** gracias a los _conda enviroments_.
#
# ### Descargar
#
# Debes [descargar](https://www.anaconda.com/distribution/#download-section) la versión de **Python 3.6** correspondiente a tu sistema operativo. Y seguir las instrucciones correspondientes. Para mayor detalles puedes revisar: [installing-anaconda-windows](https://www.datacamp.com/community/tutorials/installing-anaconda-windows#install) o [how-to-install-anaconda-on-ubuntu-18-04-quickstart](https://www.digitalocean.com/community/tutorials/how-to-install-anaconda-on-ubuntu-18-04-quickstart)
#
#
# <div id="0.1.a.2"></div>
#
# ### Instalar Pre Requisitos
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*Y2v3PrF1rUQRUHwOcXJznA.png"></img>
#
# Una vez instalado Anaconda, puedes abrir la **Anaconda Prompt** o **CMD** en windows,  o la **terminal** en Linux o MacOS.
#
# ### Version de Python
#
# Corroboramos la instalación con:
#
# ```bash
# > python --version
# Python 3.6.4 :: Anaconda custom (64-bit)
# ```

# %%
# !python --version
# Out:
# Python 3.6.4 :: Anaconda custom (64-bit)

# %% [markdown]
# #### Instalar paquetes
#
# Para instalar cualquier modulo por lo general funcionará si utilizas uno de estos dos comandos
#
# ```
# > conda install <nombre del paquete>
# ```
#
# o
#
# ```
# > pip install <nombre del paquete>
# ```
#
# El siguiente comando instalará todos los modulos que necesitamos
#
# ```
# > conda install numpy pandas matplotlib scikit-learn seaborn tqdm jupyter
# ```
#
# Luego de la instalación podrás ejecutar el siguiente código

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# <div id="0.1.b"></div>
#
# ## Opcion B: Google Colab
#
# [Colaboratory](https://colab.research.google.com/) es una herramienta de investigación para la educación y la exploración del aprendizaje automático. Es un entorno de bloc de notas de Jupyter que se puede usar sin configuración.
#
# Colaboratory funciona con la mayoría de los principales navegadores y está probado minuciosamente en las versiones más recientes de Chrome, Firefox y Safari.
#
# Colaboratory es un proyecto de investigación de uso gratuito.
#
# * [Más Información](https://research.google.com/colaboratory/faq.html)
#
# * [Tutorial](https://colab.research.google.com/notebooks/welcome.ipynb#)

# %% [markdown]
# ### Importante
#
# Para el desarrollo del LEC se le otorgará un enlace con el laboratorio, opcionalmente podrán subir ustedes el archivo que se les entrega.
#
# Al momento de entrar al enlace **deben guardar una copia en su drive** para que no pierdan su avance al cerrar la ventana. (Archivo -> Guardar una copia en Drive...)
#
# La copia se encontrará en la sección **Colab Notebooks** en su carpeta de Google Drive para futuras ediciones.
#
# Para la entrega Colab posee la opción de **descargar .ipynb** (Archivo -> Descargar ipynb) el cual deben subir a Moodle.

# %% [markdown]
# <div id="0.2"></div>
#
# # Python
#
# <img src="https://www.python.org/static/img/python-logo.png" width="40%"></img>
#
# Python es conocido por ser un lenguaje con una sintaxis sencilla pero con un gran potencial. Su simplesa es tal que un buen programador no necesite documentar ya que el _código es la documentación_. Sin embargo, si realmente lo intentas, la complejidad de los scripts o su falta de estilo  puede provocar a que esta fácilidad se pierda.
#
# <div id="0.2.1"></div>
#
# ### Guias de Estilo
#
# Más de las veces que uno quisiera, se termina pasando más tiempo leyendo el código que escribiendo nuevo. El problema surge cuando tenemos que leer código de otras personas o incluso antiguos códigos nuestros,, es por esto que programar de manera consistente, utilizar buenos nombres y principalmente documentar el código serán de gran ayuda a afrontar esto.
#
# Las guias de estilo son una serie de pautas y recomendaciones que a adoptado la comunidad para que los programadores compartan sus códigos de manera sencilla y la labor de leer y entender código sea sencillo.
#
# #### PEP 20
#
# "Long time Pythoneer Tim Peters succinctly channels the BDFL's guiding principles for Python's design into 20 aphorisms, only 19 of which have been written down."
#
# ```python
# import this
# ```
#
#
# <div class="center">
#  <center>
#      <h3> The Zen of Python by Tim Peters</h3><br>
#     Beautiful is better than ugly.<br>
#     Explicit is better than implicit.<br>
#     Simple is better than complex.<br>
#     Complex is better than complicated.<br>
#     Flat is better than nested.<br>
#     Sparse is better than dense.<br>
#     Readability counts.<br>
#     Special cases aren't special enough to break the rules.<br>
#     Although practicality beats purity.<br>
#     Errors should never pass silently.<br>
#     Unless explicitly silenced.<br>
#     In the face of ambiguity, refuse the temptation to guess.<br>
#     There should be one-- and preferably only one --obvious way to do it.<br>
#     Although that way may not be obvious at first unless you're Dutch.<br>
#     Now is better than never.<br>
#     Although never is often better than *right* now.<br>
#     If the implementation is hard to explain, it's a bad idea.<br>
#     If the implementation is easy to explain, it may be a good idea.<br>
#     Namespaces are one honking great idea -- let's do more of those!<br>
#  </center>
# </div>

# %%
import this

# %% [markdown]
# #### PEP 8
#
# PEP 8 es una colección de pautas de sintaxis y documentación para python.
#
# Version [web](https://www.python.org/dev/peps/pep-0008/) y versión en [español](http://recursospython.com/pep8es.pdf)

# %% [markdown]
# <div id="2.2"></div>
#
# ### Comprensión de listas, Generadores e Itertools
#
# Introducción a técnicas avanzadas para la creación, iteración y modificación de listas y diccionarios.
#
# La comprensión de listas es una técnica que nos permite crear listas o diccionarios de manera comprensible y sencilla. A continuación se presentan dos formas de crear una lista: usando _comprension de listas_ o usando append.
#
# ```python
# # Append
# lista_a = []
# for i in range(10):
#     lista_a.append(i**2)
#
# # Comprension de listas
# lista_c = [i**2 for i in range(10)]
# ```
#
# #### Sintaxis
# En general se sigue la siguiente sintanxis para las listas:
#
# ```python
# # Por valores en un iterable
# l1 = [i for i in range(100)]
#
# # Condicionales
# l2 = [i/2 for i in range(100) if i%2==0]
# l3 = [1 if i%2==0 else 0 for i in range(100) ]
# ```
#
# Y para los diccionarios
#
# ```python
# # Por valores en un iterable
# d1 = { index:value for index, value in enumerate("abcdefghi") if value not in "aeiou"}
# d2 = {l1_i : l3_i for l1_i, l3_i in zip(l1, l3)}
# ```

# %% [markdown]
# <div id="2.3"></div>
#
# ### Funciones de orden superior e itertool
#
# Además tenemos a disposición elementos del paradigma funcional que nos ayudan a filtrar y manipular iterables
#
# ### Lambda
#
# La función anónima lambda nos permite definir funciones sencillas. Esto nos ahorra tener que definir en un bloque de código filtros simples o funciones que solo se utilizan una vez.
#
# Por ejemple necesitamos las funciones $f(x) = x + 2$ o un comprar dos números:
#
# ```python
# # Guardar la función en una variable
# f = lambda x: x+2
# print(f(4))
#
# # Definir y llamar la función
# es_mayor = (lambda a,b: a >= b)(3, 5)
# ```
#
# ### Map
#
# _map_ es un generador que aplica una función a cada elemento de iterable:
#
# ```python
# potencias = list(map(lambda n**2, range(100))
# ```
#
# ### Filter
#
# _filter_ filtra el iterable para aquellos valores que cumplan la condición:
#
# ```python
# consonantes = list(filter(lambda c: c not in "aeiou", "sebastian"))
# ```
#
# ### Reduce
# _reduce_ nos ayuda a realizar computos sobre los iterables:
#
# ```python
# from functools import reduce
# producto = reduce((lambda x, y: x * y), [1, 2, 3, 4])
# ```
#
#
# Para seguir explorando sobre la sintaxis avanzada de python se recomiendad los siguientes links:
#
# * [itertools](https://docs.python.org/3.6/library/itertools.html)
# * [functools](https://docs.python.org/3/library/functools.html)
# * [map, filter and reduce](http://book.pythontips.com/en/latest/map_filter.html)

# %% [markdown]
# # Python para el Data Analysis
#
# ## [Jupyter Notebook](https://jupyter.org/)
#
# <div id="0.3"></div>
#
# <div id="0.3.1"></div>
#
# <center></center>
# <img src="https://jupyter.org/assets/nav_logo.svg" width="40%"></img>
#
# **Jupyter Notebook** es una herramienta extremadamente eficiente, ya que permite unir **código** y **texto enriquezido**. Así cada computo y script se puede explicar en detalle y realizar conclusiones sobre los resultados al mismo tiempo. También puede generar **gráficos** "vivos" generados en tiempo real dentro de la herramienta además de tener soporte para **Markdown** y **HTML**.
#
# Ahora mismo estás ocupando un documento generado por jupyter notebook. Este será nuestro herramienta de desarrollo predilecta para realizar el laboratorio.
#
# Para iniciar el servidor de jupyter notebook, desde la **Anaconda Promp** o **Terminal** ejecuta:
#
# ```bash
# > jupyter notebook
# ```
# Lo que abrirá la interface en el navegador.
#
# Para mayor información puede revisar el siguiente [tutorial](https://www.adictosaltrabajo.com/2018/01/18/primeros-pasos-con-jupyter-notebook/).
#
# <div id="0.3.2"></div>
#
# ## [NumPy](http://www.numpy.org/)
#
# <img src="http://www.numpy.org/_static/numpy_logo.png" width="40%"></img>
#
# **NumPy (Numeric Python)** es el módulo de Python para el calculo cientifico, incluye soporte para el uso de **arrays n dimensionales (ndarray)**. Es requisito para la mayoria de los módulos que realizan operaciones de alto rendimiento (como los siguientes). Además incluye el submodulo **numpy.random** para la generación de variables aleatorias.
#
#
# ```python
# import numpy as np
# ```
#
# Para mayor información puede revisar el siguiente [tutorial](https://docs.scipy.org/doc/numpy/user/quickstart.html)
#
#
# <div id="0.3.2"></div>
#
# ## [SciPy](https://docs.scipy.org/doc/scipy/reference/index.html)
#
# <img src="https://docs.scipy.org/doc/scipy/reference/_static/img/scipy_org_logo.png" width="40%"></img>
#
# **scipy.stats (Scientific Python Statistics)**, Scipy es un módulo para matemáticas, ciencia e ingeniería, su submódulo stats nos proporciona herramientas parael uso de distribuciones y variables aleatorias (**random variables**) incluye soporte para el uso de **arrays n dimensionales (ndarray)**.
#
#
# ```python
# from scipy import stats
# ```
#
# Para mayor información puede revisar el siguiente [tutorial](https://docs.scipy.org/doc/scipy/reference/tutorial/stats.html)
#
#
# <div id="0.3.4"></div>
#
# ## [Pandas](http://pandas.pydata.org/)
# <img src="http://pandas.pydata.org/_static/pandas_logo.png" width="40%"></img>
#
# **Pandas (Panel Data)** es un módulo para la manipulación de tablas de datos, nos ofrece una manera conveniente para cargar, procesar, analizar y guardar datos. Su potencias se encuentra en el uso de sus dos objetos: **DataFrame** y **Series**, las representaciones de **tablas de datos** y **columnas** de una base de datos.
#
# ```python
# import pandas as pd
# ```
#
# Para mayor información puede revisar el siguiente [tutorial](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
#
#
# <div id="0.3.5"></div>
#
# ## [Matplotlib](https://matplotlib.org/index.html)
# <img src="https://matplotlib.org/_static/logo2.png" width="40%"></img>
#
# **Matplotlib** es un módulo de _plotting_ en 2D para python, es compatible con los **jupyter notebooks** y base para **seaborn**. Matplotlib busca hacer las cosas lo más simple posible, es capaz de generar plots lineales, scatter, histogramas, gráfico de barras entre otras.
#
# ```python
# import matplotlib.pyplot as plt
#
# # Mostrar los gráficos en el notebook
# %matplotlib inline
# ```
#
# Para mayor información puede revisar el siguiente [tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
#
#
# <div id="0.3.6"></div>
#
# ## [Seaborn](https://seaborn.pydata.org/)
#
# <img src="https://seaborn.pydata.org/_static/scatterplot_matrix_thumb.png?v=0.9.0" width="20%"></img>
#
# **Seaborn: statistical data visualization**, es un módulo de Python para la visualización de datos estadisticos, está basado en **matplotlib** por lo que varias sentencias son compatibles. Seaborn provee de una interface de alto nivel, haciendo sencillo el generar gráficos estadisticos atractivos y informátivos.
#
# ```python
# import seaborn as sns
# sns.set(style="darkgrid")
# ```
#
# Para mayor información puede revisar el siguiente [tutorial](https://seaborn.pydata.org/tutorial.html)
#
# ## Resumen
#
# Por lo general, cuando realices los laboratorios importarás esto al comienzo del notebook

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns;sns.set(style="darkgrid")

# %matplotlib inline

# %% [markdown]
# Cada vez que te inicias en una nueva herramienta recomiendo el uso de cheat sheets para ir aprendiendo sus comandos:
#
# * [Jupyter Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Jupyter_Notebook_Cheat_Sheet.pdf)
# * [NumPy](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf)
# * [Pandas 1](https://datacamp-community-prod.s3.amazonaws.com/fbc502d0-46b2-4e1b-b6b0-5402ff273251)
# * [Pandas 2](https://datacamp-community-prod.s3.amazonaws.com/9f0f2ae1-8bd8-4302-a67b-e17f3059d9e8)
# * [Matplotlib](https://datacamp-community-prod.s3.amazonaws.com/28b8210c-60cc-4f13-b0b4-5b4f2ad4790b)
# * [Seaborn](https://datacamp-community-prod.s3.amazonaws.com/f9f06e72-519a-4722-9912-b5de742dbac4)
# * [Scikit Learn](https://datacamp-community-prod.s3.amazonaws.com/5433fa18-9f43-44cc-b228-74672efcd116)
